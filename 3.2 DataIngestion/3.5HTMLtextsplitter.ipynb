# %%
from langchain_text_splitters import (
    HTMLHeaderTextSplitter,
)

# Define headers for splitting on h1 and h2 tags.
headers_to_split_on = [("h1", "Main Topic"), ("h2", "Sub Topic")]

splitter = HTMLHeaderTextSplitter(
    headers_to_split_on=headers_to_split_on, return_each_element=False
)

html_content = """
<html>
    <body>
        <h1>Introduction</h1>
        <p>Welcome to the introduction section.</p>
        <h2>Background</h2>
        <p>Some background details here.</p>
        <h1>Conclusion</h1>
        <p>Final thoughts.</p>
    </body>
</html>
"""

html_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)

res = html_splitter.split_text(html_content)

res
# Out:
# [Document(metadata={'Main Topic': 'Introduction'}, page_content='Introduction'),
#  Document(metadata={'Main Topic': 'Introduction'}, page_content='Welcome to the introduction section.'),
#  Document(metadata={'Main Topic': 'Introduction', 'Sub Topic': 'Background'}, page_content='Background'),
#  Document(metadata={'Main Topic': 'Introduction', 'Sub Topic': 'Background'}, page_content='Some background details here.'),
#  Document(metadata={'Main Topic': 'Conclusion'}, page_content='Conclusion'),
#  Document(metadata={'Main Topic': 'Conclusion'}, page_content='Final thoughts.')]
